# %% [markdown]
# # Task 4: Bayesian Linear Regression from scratch with BlackJAX
#
# * Implement Bayesian Linear Regression from scratch with any appropriate sampling method in BlackJAX.
# * Create your own 1d linear dataset with added noise.
# * Plot the learned predictive mean and 2 standard deviations around the mean like the below plot.

# %% [markdown]
# ### Importing Libraries

# %%
from jax import random
import jax
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1D Linear Dataset Creation with added noise

# %%
x=random.normal(random.PRNGKey(30), shape=(1000,))
noise = jax.random.normal(random.PRNGKey(42), (1000,))
true_w, true_b = 2, -1
ys = x * true_w + true_b + noise
data = pd.DataFrame(dict(x=x, y=ys))
data.plot(x='x',y='y',kind="scatter")

# %% [markdown]
# Due to time constraint, the task is not completed.
